# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #1- Clustering

# %%
# Loading Data 
df_BTC = pd.read_csv('/content/drive/MyDrive/NAICo/Cleaned Data/BTC_Data.csv')
df_Oil = pd.read_csv('/content/drive/MyDrive/NAICo/Cleaned Data/Oil_Data.csv')
df_Gold = pd.read_csv('/content/drive/MyDrive/NAICo/Cleaned Data/Gold_Data.csv')

df_BTC.head()
# Out:
#          Date   Close    Open       RoR
# 0  2017-05-17  1801.3  1729.3  0.041635
# 1  2017-05-18  1881.0  1801.3  0.044246
# 2  2017-05-19  1962.0  1881.0  0.043062
# 3  2017-05-20  2040.2  1962.0  0.039857
# 4  2017-05-21  2044.2  2040.2  0.001961

# %%
# Change Date dtype to datetime 
df_BTC['Date'] = pd.to_datetime(df_BTC['Date'])
df_Oil['Date'] = pd.to_datetime(df_Oil['Date'])
df_Gold['Date'] = pd.to_datetime(df_Gold['Date'])

# %%
plt.plot(df_BTC['Date'], df_BTC['Open'], label='BTC')
# plt.title('BTC')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.legend()
plt.show()

# %%
plt.hist(np.array(df_BTC['RoR']) , bins=100, label='BTC, 5 years', histtype='step')
# plt.title('BTC')
plt.xlabel('RoR')
plt.legend()
# plt.ylabel('')
plt.show()

# %%
# Assigning cluster labels -1, 0, 1 
def assign_label(fid_eff_val):
    if fid_eff_val <= -0.05:
        return -1
    elif fid_eff_val <= 0.05:
        return 0
    else:
        return 1
    
df_BTC['label'] = df_BTC['RoR'].apply(lambda x: assign_label(x)).astype(int)

# %%
print(df_BTC.shape)
print(df_BTC['label'].value_counts())
df_BTC.head(5)
# Out:
# (1826, 5)
#  0    1503
#  1     169
# -1     154
# Name: label, dtype: int64
#         Date   Close    Open       RoR  label
# 0 2017-05-17  1801.3  1729.3  0.041635      0
# 1 2017-05-18  1881.0  1801.3  0.044246      0
# 2 2017-05-19  1962.0  1881.0  0.043062      0
# 3 2017-05-20  2040.2  1962.0  0.039857      0
# 4 2017-05-21  2044.2  2040.2  0.001961      0

# %% [markdown]
# #2- Data Analysis

# %%
# Merge RoR values for similar dates
inner_merged_RoR = pd.merge(df_BTC[['Date', 'RoR', 'label']], df_Oil[['Date', 'RoR']], on=['Date'])
inner_merged_RoR = pd.merge(inner_merged_RoR, df_Gold[['Date', 'RoR']], on=['Date'])

# Rename Column names
inner_merged_RoR = inner_merged_RoR.rename(columns={'RoR_x': 'RoR_BTC', 'RoR_y': 'RoR_Oil', 'RoR': 'RoR_Gold'}) 

inner_merged_RoR.head()
# Out:
#         Date   RoR_BTC  label   RoR_Oil  RoR_Gold
# 0 2017-05-17  0.041635      0  0.017417  0.017378
# 1 2017-05-18  0.044246      0  0.008584 -0.006818
# 2 2017-05-19  0.043062      0  0.021307  0.005454
# 3 2017-05-22  0.039233      0  0.002569  0.003101
# 4 2017-05-23  0.069761      1  0.008425 -0.003888

# %%
sns.pairplot(inner_merged_RoR.drop(['Date', 'label'], axis=1))
plt.show()

# %%
print('BTC vs Oil CorrCoef:', np.corrcoef(inner_merged_RoR['RoR_Oil'], inner_merged_RoR['RoR_BTC'])[0,1] )
print('BTC vs Gold CorrCoef:', np.corrcoef(inner_merged_RoR['RoR_Gold'], inner_merged_RoR['RoR_BTC'])[0,1] )
# Out:
# BTC vs Oil CorrCoef: 0.07193365605461535
# BTC vs Gold CorrCoef: 0.06671539670702442

# %%
cor_BTC_Oil = []
shift_range = np.arange(-20, 21, 1)
for shift in shift_range:
  if shift < 0:
    x = inner_merged_RoR['RoR_BTC'][:shift]
    y = inner_merged_RoR['RoR_Oil'][-1*shift:]
    cor = np.corrcoef(x, y)[0,1]
    cor_BTC_Oil.append(cor)
  elif shift == 0:
    x = inner_merged_RoR['RoR_BTC']
    y = inner_merged_RoR['RoR_Oil']
    cor = np.corrcoef(x, y)[0,1]
    cor_BTC_Oil.append(cor)
  else:
    x = inner_merged_RoR['RoR_BTC'][shift:]
    y = inner_merged_RoR['RoR_Oil'][:-1*shift]
    cor = np.corrcoef(x, y)[0,1]
    cor_BTC_Oil.append(cor)

print(np.abs(cor_BTC_Oil))
# Out:
# [0.01687996 0.0068115  0.01037859 0.01318901 0.01363031 0.04370426
#  0.04006456 0.04287418 0.03526973 0.02093353 0.03983749 0.0423091
#  0.04065622 0.02863575 0.06838016 0.03630355 0.0914964  0.03127314
#  0.04225174 0.03136904 0.07193366 0.03335495 0.0242115  0.02186531
#  0.00650254 0.00296151 0.02005544 0.01816104 0.06726076 0.00405807
#  0.01125827 0.01199136 0.03116688 0.02169559 0.00987098 0.00325869
#  0.04079119 0.00020584 0.03507461 0.0119428  0.01728412]

# %%
plt.plot(shift_range, np.abs(cor_BTC_Oil), label='BTC vs Oil')
# plt.title('BTC')
plt.xlabel('Shift')
plt.ylabel('Corr Coef')
plt.legend()
plt.show()

# %%
cor_BTC_Gold = []
shift_range = np.arange(-20, 21, 1)
for shift in shift_range:
  if shift < 0:
    x = inner_merged_RoR['RoR_BTC'][:shift]
    y = inner_merged_RoR['RoR_Gold'][-1*shift:]
    cor = np.corrcoef(x, y)[0,1]
    cor_BTC_Gold.append(cor)
  elif shift == 0:
    x = inner_merged_RoR['RoR_BTC']
    y = inner_merged_RoR['RoR_Gold']
    cor = np.corrcoef(x, y)[0,1]
    cor_BTC_Gold.append(cor)
  else:
    x = inner_merged_RoR['RoR_BTC'][shift:]
    y = inner_merged_RoR['RoR_Gold'][:-1*shift]
    cor = np.corrcoef(x, y)[0,1]
    cor_BTC_Gold.append(cor)

print(np.abs(cor_BTC_Gold))
# Out:
# [0.02844719 0.03125598 0.00180373 0.0155865  0.05435037 0.01279082
#  0.02500733 0.00342079 0.02906825 0.016616   0.0316701  0.00262599
#  0.02913508 0.09545092 0.02077897 0.00541024 0.05421526 0.01211167
#  0.06012624 0.01346404 0.0667154  0.01556187 0.03912194 0.03133844
#  0.05537841 0.04106445 0.04955534 0.00460503 0.00475197 0.02661944
#  0.01743965 0.01243976 0.02078458 0.07035035 0.02527373 0.06189085
#  0.03738754 0.03098096 0.01752181 0.01227768 0.02592113]

# %%
plt.plot(shift_range, np.abs(cor_BTC_Gold), label='BTC vs Gold')
# plt.title('BTC')
plt.xlabel('Shift')
plt.ylabel('Corr Coef')
plt.legend()
plt.show()

# %% [markdown]
# #3- ML

# %%
data_clus = df_BTC['RoR']
n_ts = 4
n_f = 1

# %%
def prepare_time_seqs(data):
    output_df = pd.DataFrame()
    for i in range(n_ts):
        output_df[n_ts-i] = data.shift(n_ts-i)
    output_df['target'] = data     
    return output_df

# %%
df = prepare_time_seqs(data_clus)
df['target_clus'] = df['target'].apply(lambda x: assign_label(x)).astype(int)
df.head(10)
# Out:
#           4         3         2         1    target  target_clus
# 0       NaN       NaN       NaN       NaN  0.041635            0
# 1       NaN       NaN       NaN  0.041635  0.044246            0
# 2       NaN       NaN  0.041635  0.044246  0.043062            0
# 3       NaN  0.041635  0.044246  0.043062  0.039857            0
# 4  0.041635  0.044246  0.043062  0.039857  0.001961            0
# 5  0.044246  0.043062  0.039857  0.001961  0.039233            0
# 6  0.043062  0.039857  0.001961  0.039233  0.069761            1
# 7  0.039857  0.001961  0.039233  0.069761  0.075992            1
# 8  0.001961  0.039233  0.069761  0.075992 -0.056476           -1
# 9  0.039233  0.069761  0.075992 -0.056476 -0.026918            0

# %%
df.dropna(axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#           4         3         2         1    target  target_clus
# 0  0.041635  0.044246  0.043062  0.039857  0.001961            0
# 1  0.044246  0.043062  0.039857  0.001961  0.039233            0
# 2  0.043062  0.039857  0.001961  0.039233  0.069761            1
# 3  0.039857  0.001961  0.039233  0.069761  0.075992            1
# 4  0.001961  0.039233  0.069761  0.075992 -0.056476           -1

# %% [markdown]
# Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
#train test split

train_split, test_split = train_test_split(df, random_state = 42, test_size = 0.2)

# %%
#resampling

train_neg = train_split[train_split['target_clus'] == -1]
train_zero = train_split[train_split['target_clus'] == 0]
train_pos = train_split[train_split['target_clus'] == 1]
print(len(train_neg), len(train_zero), len(train_pos))

train_neg_resampled = resample(train_neg, replace=True, n_samples=len(train_split) // 3, random_state=42)
train_zero_resampled = resample(train_zero, replace=True, n_samples=len(train_split) // 3, random_state=42)
train_pos_resampled = resample(train_pos, replace=True, n_samples=len(train_split) // 3, random_state=42)
print(len(train_neg_resampled), len(train_zero_resampled), len(train_pos_resampled))

train_resampled = pd.concat([train_neg_resampled, train_zero_resampled, train_pos_resampled])

y_train = train_resampled['target_clus'].to_numpy()
X_train = train_resampled.drop(columns = ['target_clus', 'target']).to_numpy()
y_test = test_split['target_clus'].to_numpy()
X_test = test_split.drop(columns = ['target_clus', 'target']).to_numpy()
# Out:
# 120 1197 140
# 485 485 485

# %%
plt.hist(train_resampled['target'] , bins=100, label='BTC, 5 years', histtype='step')
plt.xlabel('RoR')
plt.legend()
plt.show()

# %%
#SVM Classfier

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
svm = make_pipeline(StandardScaler(), SVC(C = 0.01, kernel = 'rbf'))
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)

# %%
from sklearn.metrics import classification_report

matrix = classification_report(y_test,y_pred)
print('Classification report : \n',matrix)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#           -1       0.17      0.32      0.22        34
#            0       0.86      0.61      0.71       302
#            1       0.08      0.24      0.12        29
#
#     accuracy                           0.55       365
#    macro avg       0.37      0.39      0.35       365
# weighted avg       0.73      0.55      0.62       365

# %% [markdown]
# Regression

# %%
df = prepare_time_seqs(data_clus)
df.head(10)
# Out:
#           4         3         2         1    target
# 0       NaN       NaN       NaN       NaN  0.041635
# 1       NaN       NaN       NaN  0.041635  0.044246
# 2       NaN       NaN  0.041635  0.044246  0.043062
# 3       NaN  0.041635  0.044246  0.043062  0.039857
# 4  0.041635  0.044246  0.043062  0.039857  0.001961
# 5  0.044246  0.043062  0.039857  0.001961  0.039233
# 6  0.043062  0.039857  0.001961  0.039233  0.069761
# 7  0.039857  0.001961  0.039233  0.069761  0.075992
# 8  0.001961  0.039233  0.069761  0.075992 -0.056476
# 9  0.039233  0.069761  0.075992 -0.056476 -0.026918

# %%
df.dropna(axis=0, inplace=True)
df *=10
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#           4         3         2         1    target
# 0  0.416353  0.442458  0.430622  0.398573  0.019606
# 1  0.442458  0.430622  0.398573  0.019606  0.392330
# 2  0.430622  0.398573  0.019606  0.392330  0.697609
# 3  0.398573  0.019606  0.392330  0.697609  0.759923
# 4  0.019606  0.392330  0.697609  0.759923 -0.564757

# %%
Y = df.target.values
X = df.drop(['target'] , axis=1).values
print(X.shape)
X = X.reshape(-1, n_ts, 1)
X.shape
# Out:
# (1822, 4)
# (1822, 4, 1)

# %%
'''
Before generating the train and validation sets, let's 
hold a portion of the data for prediction. 
We seperate the data for the last n_prediction 
days and later test to see how well our model 
can predict the target for these days. 
'''
n_prediction = 50

X_future = X[-n_prediction:]
Y_future = Y[-n_prediction:]

X = X[:-n_prediction]
Y = Y[:-n_prediction]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 0)
print(X_train.shape)
# Out:
# (1329, 4, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow import keras

# %%
model = models.Sequential()

model.add(layers.Flatten(input_shape =(n_ts, n_f) ))
model.add(layers.Dense(8, activation='relu'))
model.add(layers.Dense(1, activation='linear'))

model.compile(optimizer='adam', 
              loss=tf.keras.losses.mean_squared_error)

model.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_19 (Flatten)        (None, 4)                 0
#
#  dense_75 (Dense)            (None, 8)                 40
#
#  dense_76 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %%
his_loss = []
his_val =[]

# assign weight to each data point
sample_weight = Y_train.copy()
sample_weight[Y_train < -0.5] = 90
sample_weight[Y_train > 0.5] = 10
sample_weight[(Y_train > -0.5) & (Y_train < 0.5)] = 1
print(np.unique(sample_weight))
# Out:
# [ 1. 10. 90.]

# %%
history = model.fit(X_train,Y_train, 
                    epochs=300, batch_size = 64, 
                    verbose=1 , 
                    sample_weight= sample_weight ,
                    validation_data = (X_test, Y_test))

his_loss = np.append(his_loss, history.history['loss'])
his_val = np.append(his_val, history.history['val_loss'])
# Out:
# Epoch 1/300
# 21/21 [==============================] - 1s 9ms/step - loss: 8.1797 - val_loss: 0.2156
# Epoch 2/300
# 21/21 [==============================] - 0s 4ms/step - loss: 7.4845 - val_loss: 0.2289
# Epoch 3/300
# 21/21 [==============================] - 0s 4ms/step - loss: 6.8749 - val_loss: 0.2452
# Epoch 4/300
# 21/21 [==============================] - 0s 3ms/step - loss: 6.4318 - val_loss: 0.2635
# Epoch 5/300
# 21/21 [==============================] - 0s 3ms/step - loss: 6.0280 - val_loss: 0.2806
# Epoch 6/300
# 21/21 [==============================] - 0s 3ms/step - loss: 5.7662 - val_loss: 0.3030
# Epoch 7/300
# 21/21 [==============================] - 0s 3ms/step - loss: 5.4832 - val_loss: 0.3194
# Epoch 8/300
# 21/21 [==============================] - 0s 4ms/step - loss: 5.2894 - val_loss: 0.3394
# Epoch 9/300
# 21/21 [==============================] - 0s 3ms/step - loss: 5.0831 - val_loss: 0.3491
# Epoch 10/300
# 21/21 [==============================] - 0s 4ms/step - loss: 4.9409 - val_loss: 0.3643
# Epoch 11/300
# 21/21 [==============================] - 0s 4ms/step - loss: 4.7934 - val_loss: 0.3789
# Epoch 12/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.6744 - val_loss: 0.3878
# Epoch 13/300
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5709 - val_loss: 0.3973
# Epoch 14/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.4777 - val_loss: 0.4055
# Epoch 15/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.3934 - val_loss: 0.4135
# Epoch 16/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.3254 - val_loss: 0.4237
# Epoch 17/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.2543 - val_loss: 0.4268
# Epoch 18/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.1949 - val_loss: 0.4333
# Epoch 19/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.1440 - val_loss: 0.4381
# Epoch 20/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.0903 - val_loss: 0.4407
# Epoch 21/300
# 21/21 [==============================] - 0s 3ms/step - loss: 4.0515 - val_loss: 0.4485
# Epoch 22/300
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0066 - val_loss: 0.4504
# Epoch 23/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9616 - val_loss: 0.4555
# Epoch 24/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9215 - val_loss: 0.4616
# Epoch 25/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.8961 - val_loss: 0.4652
# Epoch 26/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.8601 - val_loss: 0.4689
# Epoch 27/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8433 - val_loss: 0.4754
# Epoch 28/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.8178 - val_loss: 0.4737
# Epoch 29/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.8031 - val_loss: 0.4788
# Epoch 30/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7871 - val_loss: 0.4783
# Epoch 31/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7772 - val_loss: 0.4844
# Epoch 32/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7637 - val_loss: 0.4833
# Epoch 33/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7559 - val_loss: 0.4867
# Epoch 34/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7466 - val_loss: 0.4831
# Epoch 35/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7435 - val_loss: 0.4914
# Epoch 36/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7345 - val_loss: 0.4912
# Epoch 37/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7313 - val_loss: 0.4862
# Epoch 38/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7243 - val_loss: 0.4893
# Epoch 39/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7205 - val_loss: 0.4922
# Epoch 40/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7162 - val_loss: 0.4899
# Epoch 41/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7139 - val_loss: 0.4955
# Epoch 42/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7109 - val_loss: 0.4903
# Epoch 43/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7097 - val_loss: 0.4913
# Epoch 44/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.7045 - val_loss: 0.4929
# Epoch 45/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7073 - val_loss: 0.5042
# Epoch 46/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6979 - val_loss: 0.5001
# Epoch 47/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6952 - val_loss: 0.4906
# Epoch 48/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6959 - val_loss: 0.4939
# Epoch 49/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6913 - val_loss: 0.4927
# Epoch 50/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6934 - val_loss: 0.4963
# Epoch 51/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6882 - val_loss: 0.4925
# Epoch 52/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6875 - val_loss: 0.4912
# Epoch 53/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6853 - val_loss: 0.4957
# Epoch 54/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6814 - val_loss: 0.4955
# Epoch 55/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6814 - val_loss: 0.4917
# Epoch 56/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6797 - val_loss: 0.4935
# Epoch 57/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6747 - val_loss: 0.4902
# Epoch 58/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6742 - val_loss: 0.4988
# Epoch 59/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6709 - val_loss: 0.4952
# Epoch 60/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6704 - val_loss: 0.4984
# Epoch 61/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6720 - val_loss: 0.4899
# Epoch 62/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6647 - val_loss: 0.4926
# Epoch 63/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6620 - val_loss: 0.4993
# Epoch 64/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6607 - val_loss: 0.4977
# Epoch 65/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6587 - val_loss: 0.4946
# Epoch 66/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6584 - val_loss: 0.5011
# Epoch 67/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6547 - val_loss: 0.4964
# Epoch 68/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6573 - val_loss: 0.4882
# Epoch 69/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6503 - val_loss: 0.4976
# Epoch 70/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6511 - val_loss: 0.4940
# Epoch 71/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6469 - val_loss: 0.4995
# Epoch 72/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6454 - val_loss: 0.4934
# Epoch 73/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6429 - val_loss: 0.4931
# Epoch 74/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6444 - val_loss: 0.4995
# Epoch 75/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6387 - val_loss: 0.4915
# Epoch 76/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6373 - val_loss: 0.4957
# Epoch 77/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6346 - val_loss: 0.4935
# Epoch 78/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6364 - val_loss: 0.4953
# Epoch 79/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6317 - val_loss: 0.4948
# Epoch 80/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6327 - val_loss: 0.4889
# Epoch 81/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6310 - val_loss: 0.4882
# Epoch 82/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6306 - val_loss: 0.4873
# Epoch 83/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6231 - val_loss: 0.4973
# Epoch 84/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6222 - val_loss: 0.4994
# Epoch 85/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6200 - val_loss: 0.4973
# Epoch 86/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6196 - val_loss: 0.4983
# Epoch 87/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6170 - val_loss: 0.4946
# Epoch 88/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6175 - val_loss: 0.4945
# Epoch 89/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6127 - val_loss: 0.4939
# Epoch 90/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6126 - val_loss: 0.4929
# Epoch 91/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6105 - val_loss: 0.4989
# Epoch 92/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6114 - val_loss: 0.4967
# Epoch 93/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6073 - val_loss: 0.5012
# Epoch 94/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6059 - val_loss: 0.5010
# Epoch 95/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6056 - val_loss: 0.4979
# Epoch 96/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6034 - val_loss: 0.4965
# Epoch 97/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6027 - val_loss: 0.4932
# Epoch 98/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6002 - val_loss: 0.4949
# Epoch 99/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5986 - val_loss: 0.4977
# Epoch 100/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5945 - val_loss: 0.4967
# Epoch 101/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5932 - val_loss: 0.4946
# Epoch 102/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5895 - val_loss: 0.4961
# Epoch 103/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5939 - val_loss: 0.4906
# Epoch 104/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5844 - val_loss: 0.4992
# Epoch 105/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5899 - val_loss: 0.5039
# Epoch 106/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5788 - val_loss: 0.4952
# Epoch 107/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5798 - val_loss: 0.4959
# Epoch 108/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5764 - val_loss: 0.4926
# Epoch 109/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5789 - val_loss: 0.4933
# Epoch 110/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5737 - val_loss: 0.4928
# Epoch 111/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5729 - val_loss: 0.4912
# Epoch 112/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5693 - val_loss: 0.4990
# Epoch 113/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5689 - val_loss: 0.4977
# Epoch 114/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5706 - val_loss: 0.4939
# Epoch 115/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5639 - val_loss: 0.5017
# Epoch 116/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5633 - val_loss: 0.5010
# Epoch 117/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5620 - val_loss: 0.4978
# Epoch 118/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5630 - val_loss: 0.5010
# Epoch 119/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5577 - val_loss: 0.4986
# Epoch 120/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5618 - val_loss: 0.4944
# Epoch 121/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5542 - val_loss: 0.4990
# Epoch 122/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5541 - val_loss: 0.5010
# Epoch 123/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5525 - val_loss: 0.4986
# Epoch 124/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5504 - val_loss: 0.4965
# Epoch 125/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5466 - val_loss: 0.4950
# Epoch 126/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5490 - val_loss: 0.4895
# Epoch 127/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5446 - val_loss: 0.4947
# Epoch 128/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5406 - val_loss: 0.4980
# Epoch 129/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5408 - val_loss: 0.5012
# Epoch 130/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5459 - val_loss: 0.4962
# Epoch 131/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5363 - val_loss: 0.4978
# Epoch 132/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5380 - val_loss: 0.5034
# Epoch 133/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5371 - val_loss: 0.4966
# Epoch 134/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5370 - val_loss: 0.5036
# Epoch 135/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5329 - val_loss: 0.4936
# Epoch 136/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5328 - val_loss: 0.4960
# Epoch 137/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5334 - val_loss: 0.5022
# Epoch 138/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5310 - val_loss: 0.4948
# Epoch 139/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5277 - val_loss: 0.4932
# Epoch 140/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5254 - val_loss: 0.4988
# Epoch 141/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5199 - val_loss: 0.4982
# Epoch 142/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5203 - val_loss: 0.4990
# Epoch 143/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5180 - val_loss: 0.4954
# Epoch 144/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5148 - val_loss: 0.4988
# Epoch 145/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5181 - val_loss: 0.5056
# Epoch 146/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5189 - val_loss: 0.4935
# Epoch 147/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5103 - val_loss: 0.4976
# Epoch 148/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5108 - val_loss: 0.5012
# Epoch 149/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5094 - val_loss: 0.4966
# Epoch 150/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5079 - val_loss: 0.4950
# Epoch 151/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5079 - val_loss: 0.4925
# Epoch 152/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5028 - val_loss: 0.4967
# Epoch 153/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.5028 - val_loss: 0.4958
# Epoch 154/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4994 - val_loss: 0.5043
# Epoch 155/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4985 - val_loss: 0.5004
# Epoch 156/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4987 - val_loss: 0.5015
# Epoch 157/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4996 - val_loss: 0.4993
# Epoch 158/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4943 - val_loss: 0.4907
# Epoch 159/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4951 - val_loss: 0.4894
# Epoch 160/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4938 - val_loss: 0.5013
# Epoch 161/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4890 - val_loss: 0.4955
# Epoch 162/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4877 - val_loss: 0.4998
# Epoch 163/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4863 - val_loss: 0.5016
# Epoch 164/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4868 - val_loss: 0.4960
# Epoch 165/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4851 - val_loss: 0.4956
# Epoch 166/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4824 - val_loss: 0.4979
# Epoch 167/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4835 - val_loss: 0.4961
# Epoch 168/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4792 - val_loss: 0.5000
# Epoch 169/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4835 - val_loss: 0.5052
# Epoch 170/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4755 - val_loss: 0.4974
# Epoch 171/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4776 - val_loss: 0.4910
# Epoch 172/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4738 - val_loss: 0.4982
# Epoch 173/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4732 - val_loss: 0.5026
# Epoch 174/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4774 - val_loss: 0.4957
# Epoch 175/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4732 - val_loss: 0.4970
# Epoch 176/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4701 - val_loss: 0.4971
# Epoch 177/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4724 - val_loss: 0.5036
# Epoch 178/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4729 - val_loss: 0.4977
# Epoch 179/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4706 - val_loss: 0.5048
# Epoch 180/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4702 - val_loss: 0.4954
# Epoch 181/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4631 - val_loss: 0.4958
# Epoch 182/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4627 - val_loss: 0.4998
# Epoch 183/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4642 - val_loss: 0.5014
# Epoch 184/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4601 - val_loss: 0.4990
# Epoch 185/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4614 - val_loss: 0.4976
# Epoch 186/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4574 - val_loss: 0.4967
# Epoch 187/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4582 - val_loss: 0.5019
# Epoch 188/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4537 - val_loss: 0.4968
# Epoch 189/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4562 - val_loss: 0.4975
# Epoch 190/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4548 - val_loss: 0.5022
# Epoch 191/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4603 - val_loss: 0.4873
# Epoch 192/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4523 - val_loss: 0.5030
# Epoch 193/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4517 - val_loss: 0.5033
# Epoch 194/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4484 - val_loss: 0.4998
# Epoch 195/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4469 - val_loss: 0.4978
# Epoch 196/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4522 - val_loss: 0.4871
# Epoch 197/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4503 - val_loss: 0.5044
# Epoch 198/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4476 - val_loss: 0.5040
# Epoch 199/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4444 - val_loss: 0.4969
# Epoch 200/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4494 - val_loss: 0.4913
# Epoch 201/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4437 - val_loss: 0.5008
# Epoch 202/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4407 - val_loss: 0.5018
# Epoch 203/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4423 - val_loss: 0.4938
# Epoch 204/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4418 - val_loss: 0.5027
# Epoch 205/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4404 - val_loss: 0.4984
# Epoch 206/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4394 - val_loss: 0.4977
# Epoch 207/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4380 - val_loss: 0.4951
# Epoch 208/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4381 - val_loss: 0.5006
# Epoch 209/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4351 - val_loss: 0.5006
# Epoch 210/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4355 - val_loss: 0.5035
# Epoch 211/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4349 - val_loss: 0.4971
# Epoch 212/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4358 - val_loss: 0.5016
# Epoch 213/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4336 - val_loss: 0.5030
# Epoch 214/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4307 - val_loss: 0.4974
# Epoch 215/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4319 - val_loss: 0.4968
# Epoch 216/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4288 - val_loss: 0.5057
# Epoch 217/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4264 - val_loss: 0.4973
# Epoch 218/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4278 - val_loss: 0.5011
# Epoch 219/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4279 - val_loss: 0.4930
# Epoch 220/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4240 - val_loss: 0.5004
# Epoch 221/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4302 - val_loss: 0.4927
# Epoch 222/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4238 - val_loss: 0.4985
# Epoch 223/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4260 - val_loss: 0.4983
# Epoch 224/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4219 - val_loss: 0.5008
# Epoch 225/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4246 - val_loss: 0.4966
# Epoch 226/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4217 - val_loss: 0.4999
# Epoch 227/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4197 - val_loss: 0.4996
# Epoch 228/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4199 - val_loss: 0.5046
# Epoch 229/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4187 - val_loss: 0.4975
# Epoch 230/300
# 21/21 [==============================] - 0s 5ms/step - loss: 3.4180 - val_loss: 0.4995
# Epoch 231/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4190 - val_loss: 0.5002
# Epoch 232/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4141 - val_loss: 0.4943
# Epoch 233/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4160 - val_loss: 0.5026
# Epoch 234/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4187 - val_loss: 0.5069
# Epoch 235/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4113 - val_loss: 0.4923
# Epoch 236/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4166 - val_loss: 0.4911
# Epoch 237/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4103 - val_loss: 0.5031
# Epoch 238/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4108 - val_loss: 0.4959
# Epoch 239/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4139 - val_loss: 0.5021
# Epoch 240/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4076 - val_loss: 0.4964
# Epoch 241/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4123 - val_loss: 0.4912
# Epoch 242/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.4068 - val_loss: 0.4928
# Epoch 243/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4069 - val_loss: 0.4987
# Epoch 244/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4029 - val_loss: 0.4989
# Epoch 245/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4006 - val_loss: 0.4955
# Epoch 246/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.4030 - val_loss: 0.4889
# Epoch 247/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3971 - val_loss: 0.4965
# Epoch 248/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3996 - val_loss: 0.4944
# Epoch 249/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3987 - val_loss: 0.4987
# Epoch 250/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3963 - val_loss: 0.4942
# Epoch 251/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3951 - val_loss: 0.4919
# Epoch 252/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3958 - val_loss: 0.4958
# Epoch 253/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3956 - val_loss: 0.4973
# Epoch 254/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3943 - val_loss: 0.4973
# Epoch 255/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3965 - val_loss: 0.4961
# Epoch 256/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3906 - val_loss: 0.4937
# Epoch 257/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3903 - val_loss: 0.4933
# Epoch 258/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3912 - val_loss: 0.4883
# Epoch 259/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3922 - val_loss: 0.4991
# Epoch 260/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3894 - val_loss: 0.4983
# Epoch 261/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3857 - val_loss: 0.4935
# Epoch 262/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3840 - val_loss: 0.4950
# Epoch 263/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3896 - val_loss: 0.4876
# Epoch 264/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3879 - val_loss: 0.4879
# Epoch 265/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3778 - val_loss: 0.5003
# Epoch 266/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3855 - val_loss: 0.4955
# Epoch 267/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3837 - val_loss: 0.4984
# Epoch 268/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3809 - val_loss: 0.4987
# Epoch 269/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3807 - val_loss: 0.5029
# Epoch 270/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3795 - val_loss: 0.4894
# Epoch 271/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3773 - val_loss: 0.4926
# Epoch 272/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3797 - val_loss: 0.5025
# Epoch 273/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3823 - val_loss: 0.4873
# Epoch 274/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3760 - val_loss: 0.4937
# Epoch 275/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3738 - val_loss: 0.4956
# Epoch 276/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3728 - val_loss: 0.5001
# Epoch 277/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3701 - val_loss: 0.4956
# Epoch 278/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3712 - val_loss: 0.4906
# Epoch 279/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3683 - val_loss: 0.4926
# Epoch 280/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3699 - val_loss: 0.4870
# Epoch 281/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3704 - val_loss: 0.4984
# Epoch 282/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3659 - val_loss: 0.4949
# Epoch 283/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3638 - val_loss: 0.4926
# Epoch 284/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3667 - val_loss: 0.4914
# Epoch 285/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3623 - val_loss: 0.4966
# Epoch 286/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3614 - val_loss: 0.4961
# Epoch 287/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3612 - val_loss: 0.4883
# Epoch 288/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3607 - val_loss: 0.4908
# Epoch 289/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3598 - val_loss: 0.4897
# Epoch 290/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3589 - val_loss: 0.4936
# Epoch 291/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3612 - val_loss: 0.4854
# Epoch 292/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3564 - val_loss: 0.4960
# Epoch 293/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3552 - val_loss: 0.4954
# Epoch 294/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3572 - val_loss: 0.4877
# Epoch 295/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3549 - val_loss: 0.4898
# Epoch 296/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3496 - val_loss: 0.4999
# Epoch 297/300
# 21/21 [==============================] - 0s 3ms/step - loss: 3.3573 - val_loss: 0.4917
# Epoch 298/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3502 - val_loss: 0.4960
# Epoch 299/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3537 - val_loss: 0.4976
# Epoch 300/300
# 21/21 [==============================] - 0s 4ms/step - loss: 3.3494 - val_loss: 0.4899

# %%
fig = plt.figure(figsize=(7,5))
# Plot training & validation loss values
ax = fig.add_subplot(1,1,1, title = 'Model loss', ylabel= 'Loss')
plt.plot(his_loss)
plt.plot(his_val)
plt.legend(['Train', 'Test'])

plt.tight_layout()
plt.show()

# %%
y_test = Y_test
y_pred = model.predict(X_test)

# %%
y_test[y_test < -0.5] = -1
y_test[y_test > 0.5] = 1
y_test[(y_test > -0.5) & (y_test < 0.5)] = 0

y_pred[y_pred < -0.5] = -1
y_pred[y_pred > 0.5] = 1
y_pred[(y_pred > -0.5) & (y_pred < 0.5)] = 0

# %%
from sklearn.metrics import classification_report

matrix = classification_report(y_test,y_pred,labels=[1,0, -1])
print('Classification report : \n',matrix)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            1       1.00      0.02      0.05        42
#            0       0.82      0.44      0.58       366
#           -1       0.08      0.57      0.14        35
#
#     accuracy                           0.41       443
#    macro avg       0.63      0.35      0.25       443
# weighted avg       0.78      0.41      0.49       443

# %%
Y_fut_predicted = model.predict(X_future)
plt.plot(Y_future, label = 'Real Data')
plt.plot(Y_fut_predicted, label = 'Predicted values')
plt.legend(loc=0)
plt.show()
